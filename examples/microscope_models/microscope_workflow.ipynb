# %% [markdown]
# # Microscope workflow
#
# 1. Solve/export design curves.
# 2. Build the microscope and trace rays.
# 3. Display generated images.

# %%
# %run examples/microscope_models/solve_design_curves.py

# %%
# %run examples/microscope_models/create_and_trace_microscope.py

# %%
from pathlib import Path
from IPython.display import Image, display

output_dir = Path('examples/microscope_models/output')
for name in ('sample_intensity.png', 'ray_diagram.png'):
    path = output_dir / name
    print(path)
    display(Image(filename=str(path)))
